# %% [markdown]
# Time complexity : Rate of increase in time with respect to input size
# TC -> Big-O Notation -> O() # total number of operation happens
#
# # rules to calculate time complexity
# 1. always calculate tc in terms of worst -case
# 2. Avoide the constant values
# 3. Avoide lower Bound

# %%
age = 10
if age >=90:
  print("ss")
elif age >= 60 and age >= 90:
  print("Senior")
elif age >= 24 and age >= 60:
  print("working")
elif age >= 16 and age>= 24:
  print("teen")
else:
  print("child")    
 # Rule1. if your code work in worst case that mean your code us suficient
# Out:
# child

# %%
#Fraction of Digits
# - Count Digits
# - Reverse a number
# - Check palindrome
# - Armstrong number

# print digit one by one and extract
n = 5873
num= n
while num>0:
  last_digit = num% 10
  print(last_digit)
  num=num//10
# Out:
# 3
# 7
# 8
# 5

# %%
# Count digit
count = 0
n= 5873
num = n
while num>0:
  count+=1
  num = num//10
print( count)
# Out:
# 4

# %%
# Logrithmic based approach
from math import *
def count_digits(num):
  return int(log10(num)+1)
count_digits(num)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       3 def count_digits(num):
#       4   return int(log10(num)+1)
# ----> 5 count_digits(num)
#
# NameError: name 'num' is not defined

# %%
# check if num is palindrome
# palindrome is something which read either left to right or right to left 
n = 1234
